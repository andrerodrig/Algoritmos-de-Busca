# %% [markdown]
# # Busca em Profundidade
#
# Algoritmo de busca, que, ao contrário da busca em largura, procura os nós em profundidade, indo até o nó mais profundo de um ramo da árvore. Neste caso, a estrutura de dado chave é uma pilha, em que o primeiro elemento que entra é o ultimo a sair.
#
# ***
#
# ### Problema de Busca do AIMA (Peter Norvig) - Visualização
# #### Algóritmo de busca em Profundidade - Procurando por Bucharest

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
Romenia = nx.Graph()
cidades = [
    'Oradea',
    'Zerind',
    'Arad',
    'Sibiu',
    'Timisoara',
    'Lugoj',
    'Mehadia',
    'Dobreta',
    'Fagaras',
    'Rimnicu Viicea',
    'Craiova',
    'Pitesti',
    'Bucharest',
    'Giurgiu',
    'Urziceni',
    'Hirsova',
    'Eforie',
    'Vasiui',
    'Iasi',
    'Neamt'
]

Romenia.add_nodes_from(range(1,21))

# %%
for i in range(len(Romenia.nodes)):
    Romenia.nodes[i+1]['cidade'] = cidades[i]

# %%
Romenia.nodes(data=True)
# Out:
# NodeDataView({1: {'cidade': 'Oradea'}, 2: {'cidade': 'Zerind'}, 3: {'cidade': 'Arad'}, 4: {'cidade': 'Sibiu'}, 5: {'cidade': 'Timisoara'}, 6: {'cidade': 'Lugoj'}, 7: {'cidade': 'Mehadia'}, 8: {'cidade': 'Dobreta'}, 9: {'cidade': 'Fagaras'}, 10: {'cidade': 'Rimnicu Viicea'}, 11: {'cidade': 'Craiova'}, 12: {'cidade': 'Pitesti'}, 13: {'cidade': 'Bucharest'}, 14: {'cidade': 'Giurgiu'}, 15: {'cidade': 'Urziceni'}, 16: {'cidade': 'Hirsova'}, 17: {'cidade': 'Eforie'}, 18: {'cidade': 'Vasiui'}, 19: {'cidade': 'Iasi'}, 20: {'cidade': 'Neamt'}})

# %%
Romenia.add_weighted_edges_from([
    (1, 2, 71),(1, 4, 151),
    (2, 3, 75),
    (3, 5, 118), (3, 4, 140),
    (4, 9, 99), (4, 10, 80),
    (5, 6, 111),
    (6, 7, 70),
    (7, 8, 75),
    (8, 11, 120),
    (9, 13, 211),
    (10, 11, 146), (10, 12, 97),
    (12, 13, 101),
    (13, 14, 90), (13, 15, 85),
    (15, 16, 98), (15, 18, 142),
    (16, 17, 86),
    (18, 19, 92),
    (19, 20, 87)
])

# %%
plt.figure(figsize=(15,10))

pos = nx.spring_layout(Romenia)

nx.draw(Romenia,
        pos,
        with_labels=True)
nx.draw_networkx_edge_labels(Romenia,
                             pos,
                             edge_labels={
                                 (1, 2): Romenia[1][2]['weight'],
                                 (1, 4): Romenia[1][4]['weight'],
                                 (2, 3): Romenia[2][3]['weight'],
                                 (3, 5): Romenia[3][5]['weight'],
                                 (3, 4): Romenia[3][4]['weight'],
                                 (4, 9): Romenia[4][9]['weight'],
                                 (4, 10): Romenia[4][10]['weight'],
                                 (5, 6): Romenia[5][6]['weight'],
                                 (6, 7): Romenia[6][7]['weight'],
                                 (7, 8): Romenia[7][8]['weight'],
                                 (8, 11): Romenia[8][11]['weight'],
                                 (9, 13): Romenia[9][13]['weight'],
                                 (10, 11): Romenia[10][11]['weight'],
                                 (10, 12): Romenia[10][12]['weight'],
                                 (12, 13): Romenia[12][13]['weight'],
                                 (13, 14): Romenia[13][14]['weight'],
                                 (13, 15): Romenia[13][15]['weight'],
                                 (15, 16): Romenia[15][16]['weight'],
                                 (15, 18): Romenia[15][18]['weight'],
                                 (16, 17): Romenia[16][17]['weight'],
                                 (18, 19): Romenia[18][19]['weight'],
                                 (19, 20): Romenia[19][20]['weight'],
                             })
plt.show()

# %% [markdown]
# #### Neste caso, a busca será feita começando de Oradea.

# %%
from dfs import dfs

dfs(Romenia, key='cidade', value='Bucharest')
# Out:
# (1, {'cidade': 'Oradea'})
# (4, {'cidade': 'Sibiu'})
# (10, {'cidade': 'Rimnicu Viicea'})
# (12, {'cidade': 'Pitesti'})
# (13, {'cidade': 'Bucharest'})
# (13, {'cidade': 'Bucharest'})
